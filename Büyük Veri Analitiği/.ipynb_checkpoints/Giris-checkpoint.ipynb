# %% [markdown]
# ![image.png](attachment:3b80327a-455c-40b4-bfe8-48ddb6e438df.png)

# %% [markdown]
# ![image.png](attachment:e476a215-63f8-412a-918f-2c3cc9ee2f4f.png)

# %% [markdown]
# ![image.png](attachment:ed852474-4185-4b91-90f4-2d63e69cfce9.png)

# %% [markdown]
# ![image.png](attachment:f47ee290-afea-4986-9c00-c87034e25958.png)

# %% [markdown]
# ![image.png](attachment:6cd92b86-1228-4680-8b9c-1c8f7adb1507.png)

# %% [markdown]
# ![image.png](attachment:43ab3eef-3051-48df-9ec2-b4db608fafa2.png)

# %% [markdown]
# ![image.png](attachment:e66c9b83-ad79-4d6b-9866-00e6c76b0ae0.png)
