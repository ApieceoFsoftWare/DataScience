# %% [markdown]
# ![image.png](attachment:a399cab5-ca5d-454a-9f9c-9406ad744ed2.png)

# %% [markdown]
# ![image.png](attachment:88d37408-d7db-4e24-bdb0-ffa1d8be2348.png)

# %% [markdown]
# ![image.png](attachment:b5897562-ae1e-4cfc-ab94-fad5fc14d2ed.png)

# %% [markdown]
# ![image.png](attachment:83036e3e-582c-4127-b2c7-9e32d7ed86bf.png)

# %% [markdown]
# ![image.png](attachment:d688875b-af11-4f05-8cec-00ce3654d6d1.png)
