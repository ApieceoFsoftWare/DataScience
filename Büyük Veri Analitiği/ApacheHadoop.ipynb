# %% [markdown]
# ![image.png](attachment:b7f2c995-5166-4237-bef2-3e9270c53df7.png)

# %% [markdown]
# ![image.png](attachment:58e55c4f-df11-42ed-b905-1034e8f6b7b4.png)

# %% [markdown]
# ![image.png](attachment:b68b488e-afbd-4b91-9462-7f784444dc15.png)

# %% [markdown]
# ![image.png](attachment:440e0a73-9424-497a-83f1-b401f6c3a860.png)

# %% [markdown]
# ![image.png](attachment:612167b8-80a8-40c9-961f-318723edf556.png)![image.png](attachment:f864f933-6a48-423c-b7a5-7cff10b9d370.png)

# %% [markdown]
# ![image.png](attachment:ba07435e-d781-43ad-bc9f-f07f48e25e83.png)

# %% [markdown]
# ![image.png](attachment:f62b722e-4c5b-4813-a8fc-5d0f3f150a49.png)
