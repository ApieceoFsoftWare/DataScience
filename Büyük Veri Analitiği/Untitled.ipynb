# %%
#!pip install findspark
# Out:
# Collecting findspark
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001E695B5BEB0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/findspark/
#   Downloading findspark-1.4.2-py2.py3-none-any.whl (4.2 kB)
# Installing collected packages: findspark
# Successfully installed findspark-1.4.2

# %%
import findspark
findspark.init("C:\spark")

# %%
conda install python=3.7.0
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# Note: you may need to restart the kernel to use updated packages.
# Building graph of deps:   0%|          | 0/343 [00:00<?, ?it/s]
# Examining sqlite:   0%|          | 0/343 [00:00<?, ?it/s]
# Examining ujson:   0%|          | 1/343 [00:00<00:03, 102.17it/s]
# Examining sphinxcontrib-jsmath:   1%|          | 2/343 [00:00<00:12, 27.55it/s]
# Examining cryptography:   1%|          | 3/343 [00:00<00:09, 34.26it/s]
# Examining contextlib2:   1%|1         | 4/343 [00:01<01:36,  3.53it/s]
# Examining contextlib2:   1%|1         | 5/343 [00:01<01:16,  4.41it/s]
# Examining ipywidgets:   1%|1         | 5/343 [00:01<01:16,  4.41it/s]
# Examining urllib3:   2%|1         | 6/343 [00:03<01:16,  4.41it/s]
# Examining urllib3:   2%|2         | 7/343 [00:03<03:12,  1.75it/s]
# Examining partd:   2%|2         | 7/343 [00:04<03:12,  1.75it/s]
# Examining partd:   2%|2         | 8/343 [00:04<04:08,  1.35it/s]
# Examining anaconda==2021.05:   2%|2         | 8/343 [00:04<04:08,  1.35it/s]
# Examining freetype:   3%|2         | 9/343 [00:05<04:07,  1.35it/s]
# Examining freetype:   3%|2         | 10/343 [00:05<02:45,  2.01it/s]
# Examining glob2:   3%|2         | 10/343 [00:05<02:45,  2.01it/s]
# Examining toolz:   3%|3         | 11/343 [00:05<02:45,  2.01it/s]
# Examining lzo:   3%|3         | 12/343 [00:05<02:44,  2.01it/s]
# Examining dask-core:   4%|3         | 13/343 [00:05<02:44,  2.01it/s]
# Examining jupyterlab_server:   4%|4         | 14/343 [00:05<02:43,  2.01it/s]
# Examining jupyterlab_server:   4%|4         | 15/343 [00:05<01:40,  3.27it/s]
# Examining sortedcollections:   4%|4         | 15/343 [00:06<01:40,  3.27it/s]
# Examining sortedcollections:   5%|4         | 16/343 [00:06<02:11,  2.48it/s]
# Examining nbclient:   5%|4         | 16/343 [00:06<02:11,  2.48it/s]
# Examining get_terminal_size:   5%|4         | 17/343 [00:06<02:11,  2.48it/s]
# Examining get_terminal_size:   5%|5         | 18/343 [00:06<01:39,  3.27it/s]
# Examining ply:   5%|5         | 18/343 [00:06<01:39,  3.27it/s]
# Examining jupyter_server:   6%|5         | 19/343 [00:06<01:39,  3.27it/s]
# Examining spyder-kernels:   6%|5         | 20/343 [00:07<01:38,  3.27it/s]
# Examining spyder-kernels:   6%|6         | 21/343 [00:07<01:06,  4.82it/s]
# Examining blas:   6%|6         | 21/343 [00:09<01:06,  4.82it/s]
# Examining bcrypt:   6%|6         | 22/343 [00:09<01:06,  4.82it/s]
# Examining bcrypt:   7%|6         | 23/343 [00:09<02:12,  2.41it/s]
# Examining libdeflate:   7%|6         | 23/343 [00:09<02:12,  2.41it/s]
# Examining libdeflate:   7%|6         | 24/343 [00:09<02:04,  2.55it/s]
# Examining sympy:   7%|6         | 24/343 [00:09<02:04,  2.55it/s]
# Examining networkx:   7%|7         | 25/343 [00:09<02:04,  2.55it/s]
# Examining networkx:   8%|7         | 26/343 [00:09<01:43,  3.07it/s]
# Examining python-language-server:   8%|7         | 26/343 [00:09<01:43,  3.07it/s]
# Examining python-language-server:   8%|7         | 27/343 [00:09<01:39,  3.18it/s]
# Examining testpath:   8%|7         | 27/343 [00:11<01:39,  3.18it/s]
# Examining testpath:   8%|8         | 28/343 [00:11<02:50,  1.84it/s]
# Examining wheel:   8%|8         | 28/343 [00:11<02:50,  1.84it/s]
# Examining notebook:   8%|8         | 29/343 [00:12<02:50,  1.84it/s]
# Examining notebook:   9%|8         | 30/343 [00:12<02:37,  1.99it/s]
# Examining scipy:   9%|8         | 30/343 [00:18<02:37,  1.99it/s]
# Examining scipy:   9%|9         | 31/343 [00:18<08:58,  1.73s/it]
# Examining yellowbrick:   9%|9         | 31/343 [00:20<08:58,  1.73s/it]
# Examining yellowbrick:   9%|9         | 32/343 [00:20<08:55,  1.72s/it]
# Examining nltk:   9%|9         | 32/343 [00:20<08:55,  1.72s/it]
# Examining pytest:  10%|9         | 33/343 [00:20<08:53,  1.72s/it]
# Examining pytest:  10%|9         | 34/343 [00:20<05:48,  1.13s/it]
# Examining intel-openmp:  10%|9         | 34/343 [00:25<05:48,  1.13s/it]
# Examining intel-openmp:  10%|#         | 35/343 [00:25<09:18,  1.81s/it]
# Examining pip:  10%|#         | 35/343 [00:25<09:18,  1.81s/it]
# Examining comtypes:  10%|#         | 36/343 [00:27<09:16,  1.81s/it]
# Examining comtypes:  11%|#         | 37/343 [00:27<07:55,  1.55s/it]
# Examining backcall:  11%|#         | 37/343 [00:27<07:55,  1.55s/it]
# Examining importlib-metadata:  11%|#1        | 38/343 [00:27<07:53,  1.55s/it]
# Examining pkginfo:  11%|#1        | 39/343 [00:27<07:51,  1.55s/it]
# Examining pkginfo:  12%|#1        | 40/343 [00:27<04:24,  1.15it/s]
# Examining matplotlib-base:  12%|#1        | 40/343 [00:27<04:24,  1.15it/s]
# Examining ipython:  12%|#1        | 41/343 [00:29<04:23,  1.15it/s]
# Examining ipython:  12%|#2        | 42/343 [00:29<04:16,  1.18it/s]
# Examining packaging:  12%|#2        | 42/343 [00:30<04:16,  1.18it/s]
# Examining packaging:  13%|#2        | 43/343 [00:30<05:10,  1.04s/it]
# Examining pycosat:  13%|#2        | 43/343 [00:31<05:10,  1.04s/it]
# Examining pycosat:  13%|#2        | 44/343 [00:31<04:17,  1.16it/s]
# Examining jinja2:  13%|#2        | 44/343 [00:31<04:17,  1.16it/s]
# Examining pyzmq:  13%|#3        | 45/343 [00:31<04:16,  1.16it/s]
# Examining pyzmq:  13%|#3        | 46/343 [00:31<03:05,  1.60it/s]
# Examining async_generator:  13%|#3        | 46/343 [00:31<03:05,  1.60it/s]
# Examining giflib:  14%|#3        | 47/343 [00:31<03:05,  1.60it/s]
# Examining giflib:  14%|#3        | 48/343 [00:31<02:07,  2.31it/s]
# Examining libtiff:  14%|#3        | 48/343 [00:31<02:07,  2.31it/s]
# Examining sphinxcontrib-devhelp:  14%|#4        | 49/343 [00:31<02:07,  2.31it/s]
# Examining unicodecsv:  15%|#4        | 50/343 [00:31<02:06,  2.31it/s]
# Examining jupyter_client:  15%|#4        | 51/343 [00:31<02:06,  2.31it/s]
# Examining typing_extensions:  15%|#5        | 52/343 [00:32<02:05,  2.31it/s]
# Examining typing_extensions:  15%|#5        | 53/343 [00:32<01:16,  3.78it/s]
# Examining pyqt:  15%|#5        | 53/343 [00:32<01:16,  3.78it/s]
# Examining xlwings:  16%|#5        | 54/343 [00:32<01:16,  3.78it/s]
# Examining xlwings:  16%|#6        | 55/343 [00:32<01:02,  4.63it/s]
# Examining attrs:  16%|#6        | 55/343 [00:32<01:02,  4.63it/s]
# Examining greenlet:  16%|#6        | 56/343 [00:33<01:01,  4.63it/s]
# Examining greenlet:  17%|#6        | 57/343 [00:33<01:13,  3.91it/s]
# Examining psutil:  17%|#6        | 57/343 [00:33<01:13,  3.91it/s]
# Examining psutil:  17%|#6        | 58/343 [00:33<01:06,  4.31it/s]
# Examining atomicwrites:  17%|#6        | 58/343 [00:33<01:06,  4.31it/s]
# Examining atomicwrites:  17%|#7        | 59/343 [00:33<01:01,  4.64it/s]
# Examining pyopenssl:  17%|#7        | 59/343 [00:33<01:01,  4.64it/s]
# Examining imagesize:  17%|#7        | 60/343 [00:33<01:00,  4.64it/s]
# Examining imagesize:  18%|#7        | 61/343 [00:33<01:06,  4.21it/s]
# Examining @/win-64::__archspec==1=x86_64:  18%|#7        | 61/343 [00:34<01:06,  4.21it/s]
# Examining matplotlib:  18%|#8        | 62/343 [00:34<01:06,  4.21it/s]
# Examining defusedxml:  18%|#8        | 63/343 [00:37<01:06,  4.21it/s]
# Examining defusedxml:  19%|#8        | 64/343 [00:37<03:12,  1.45it/s]
# Examining mypy_extensions:  19%|#8        | 64/343 [00:37<03:12,  1.45it/s]
# Examining conda-content-trust:  19%|#8        | 65/343 [00:38<03:11,  1.45it/s]
# Examining conda-content-trust:  19%|#9        | 66/343 [00:38<02:22,  1.95it/s]
# Examining zipp:  19%|#9        | 66/343 [00:38<02:22,  1.95it/s]
# Examining pandocfilters:  20%|#9        | 67/343 [00:38<02:21,  1.95it/s]
# Examining pandocfilters:  20%|#9        | 68/343 [00:38<01:48,  2.55it/s]
# Examining astroid:  20%|#9        | 68/343 [00:38<01:48,  2.55it/s]
# Examining pickleshare:  20%|##        | 69/343 [00:41<01:47,  2.55it/s]
# Examining pickleshare:  20%|##        | 70/343 [00:41<03:08,  1.45it/s]
# Examining bleach:  20%|##        | 70/343 [00:41<03:08,  1.45it/s]
# Examining nbclassic:  21%|##        | 71/343 [00:41<03:07,  1.45it/s]
# Examining nbclassic:  21%|##        | 72/343 [00:41<02:36,  1.73it/s]
# Examining icu:  21%|##        | 72/343 [00:41<02:36,  1.73it/s]
# Examining sniffio:  21%|##1       | 73/343 [00:41<02:36,  1.73it/s]
# Examining m2w64-gmp:  22%|##1       | 74/343 [00:41<02:35,  1.73it/s]
# Examining importlib_metadata:  22%|##1       | 75/343 [00:41<02:35,  1.73it/s]
# Examining backports.functools_lru_cache:  22%|##2       | 76/343 [00:41<02:34,  1.73it/s]
# Examining backports.functools_lru_cache:  22%|##2       | 77/343 [00:41<01:19,  3.36it/s]
# Examining yapf:  22%|##2       | 77/343 [00:41<01:19,  3.36it/s]
# Examining sip:  23%|##2       | 78/343 [00:42<01:18,  3.36it/s]
# Examining sip:  23%|##3       | 79/343 [00:42<01:07,  3.93it/s]
# Examining more-itertools:  23%|##3       | 79/343 [00:42<01:07,  3.93it/s]
# Examining tifffile:  23%|##3       | 80/343 [00:42<01:06,  3.93it/s]
# Examining tifffile:  24%|##3       | 81/343 [00:42<00:58,  4.46it/s]
# Examining pyerfa:  24%|##3       | 81/343 [00:43<00:58,  4.46it/s]
# Examining alabaster:  24%|##3       | 82/343 [00:43<00:58,  4.46it/s]
# Examining alabaster:  24%|##4       | 83/343 [00:43<01:20,  3.25it/s]
# Examining snowballstemmer:  24%|##4       | 83/343 [00:43<01:20,  3.25it/s]
# Examining pynacl:  24%|##4       | 84/343 [00:43<01:19,  3.25it/s]
# Examining spyder:  25%|##4       | 85/343 [00:43<01:19,  3.25it/s]
# Examining spyder:  25%|##5       | 86/343 [00:43<00:58,  4.38it/s]
# Examining widgetsnbextension:  25%|##5       | 86/343 [00:55<00:58,  4.38it/s]
# Examining widgetsnbextension:  25%|##5       | 87/343 [00:55<08:03,  1.89s/it]
# Examining py-lief:  25%|##5       | 87/343 [00:59<08:03,  1.89s/it]
# Examining py-lief:  26%|##5       | 88/343 [00:59<09:26,  2.22s/it]
# Examining certifi:  26%|##5       | 88/343 [00:59<09:26,  2.22s/it]
# Examining powershell_shortcut:  26%|##5       | 89/343 [00:59<09:24,  2.22s/it]
# Examining powershell_shortcut:  26%|##6       | 90/343 [00:59<06:31,  1.55s/it]
# Examining cython:  26%|##6       | 90/343 [00:59<06:31,  1.55s/it]
# Examining conda[version='>=4.10.3']:  27%|##6       | 91/343 [01:02<06:30,  1.55s/it]
# Examining conda[version='>=4.10.3']:  27%|##6       | 92/343 [01:02<06:07,  1.46s/it]
# Examining docutils:  27%|##6       | 92/343 [01:02<06:07,  1.46s/it]
# Examining docutils:  27%|##7       | 93/343 [01:02<05:07,  1.23s/it]
# Examining terminado:  27%|##7       | 93/343 [01:02<05:07,  1.23s/it]
# Examining kiwisolver:  27%|##7       | 94/343 [01:02<05:06,  1.23s/it]
# Examining kiwisolver:  28%|##7       | 95/343 [01:02<03:32,  1.17it/s]
# Examining filelock:  28%|##7       | 95/343 [01:02<03:32,  1.17it/s]
# Examining cloudpickle:  28%|##7       | 96/343 [01:02<03:31,  1.17it/s]
# Examining cloudpickle:  28%|##8       | 97/343 [01:02<02:26,  1.68it/s]
# Examining brotlipy:  28%|##8       | 97/343 [01:02<02:26,  1.68it/s]
# Examining brotlipy:  29%|##8       | 98/343 [01:02<02:07,  1.91it/s]
# Examining zope.event:  29%|##8       | 98/343 [01:03<02:07,  1.91it/s]
# Examining entrypoints:  29%|##8       | 99/343 [01:03<02:07,  1.91it/s]
# Examining llvmlite:  97%|#########7| 333/343 [03:16<00:02,  3.60it/s]
# Examining future:  97%|#########7| 333/343 [03:17<00:02,  3.60it/s]
# Examining lcms2:  97%|#########7| 334/343 [03:17<00:02,  3.60it/s]
# Examining pytables:  98%|#########7| 335/343 [03:17<00:02,  3.60it/s]
# Examining pytables:  98%|#########7| 336/343 [03:17<00:01,  4.71it/s]
# Examining xlsxwriter:  98%|#########7| 336/343 [03:19<00:01,  4.71it/s]
# Examining numexpr:  98%|#########8| 337/343 [03:19<00:01,  4.71it/s]
# Examining pathspec:  99%|#########8| 338/343 [03:21<00:01,  4.71it/s]
# Examining pathspec:  99%|#########8| 339/343 [03:21<00:02,  1.70it/s]
# Examining python-libarchive-c:  99%|#########8| 339/343 [03:21<00:02,  1.70it/s]
# Examining watchdog:  99%|#########9| 340/343 [03:21<00:01,  1.70it/s]
# Examining watchdog:  99%|#########9| 341/343 [03:21<00:00,  2.04it/s]
# Examining pyreadline:  99%|#########9| 341/343 [03:22<00:00,  2.04it/s]
# Examining xz: 100%|#########9| 342/343 [03:22<00:00,  2.04it/s]
# Examining xz: 100%|##########| 343/343 [03:22<00:00,  2.51it/s]
#
#
# Determining conflicts:   0%|          | 0/343 [00:00<?, ?it/s]
# Examining conflict for sqlite ujson cytoolz bkcharts docutils terminado sphinxcontrib-jsmath kiwisolver h5py cryptography pysocks contextlib2 ipywidgets regex filelock urllib3 cloudpickle xlrd toml numexpr brotlipy statsmodels partd zope.event anaconda qtconsole mistune jsonschema pywinpty glob2 msgpack-python pytest-runner numpydoc rtree entrypoints xlsxwriter jupyter-packaging three-merge toolz parso imagecodecs olefile ipykernel markupsafe prompt_toolkit dask-core jupyterlab_server sortedcollections nbclient win_unicode_console joblib path pyflakes dask beautifulsoup4 ply xmltodict setuptools rope pillow jupyter_server spyder-kernels anaconda-client diff-match-patch itsdangerous six nest-asyncio bcrypt navigator-updater pywin32-ctypes anyio qtawesome win_inet_pton pyodbc openpyxl wincertstore pandas sympy networkx backports.tempfile jupyter python-language-server argh lazy-object-proxy requests pyyaml qtpy testpath asn1crypto conda-package-handling ruamel_yaml wheel pycurl notebook scipy scikit-image scikit-learn cycler keyring sphinxcontrib-htmlhelp tqdm python-dateutil isort jupyterlab_widgets jupyter_core sphinxcontrib-qthelp nose fsspec sphinxcontrib-serializinghtml click yellowbrick nltk mccabe black sphinx idna pytest tblib heapdict numba bottleneck chardet bitarray jdcal wcwidth typed-ast locket pip decorator comtypes backcall importlib-metadata ptyprocess jedi pkginfo wrapt matplotlib-base distributed ipython packaging sphinxcontrib pycosat pywin32 anaconda-navigator jinja2 colorama pathlib2 pyzmq mpmath pycodestyle async_generator sphinxcontrib-applehelp clyent conda-token webencodings sphinxcontrib-devhelp unicodecsv prompt-toolkit jupyter_client typing_extensions jupyterlab_pygments fastcache pywavelets zope.interface pyqt flask tornado numpy-base xlwings qdarkstyle textdistance patsy attrs imageio send2trash zope pep8 sortedcontainers greenlet flake8 pylint python-jsonrpc-server psutil pycparser nbconvert conda-verify atomicwrites backports pyopenssl imagesize backports.shutil_get_terminal_size pydocstyle matplotlib seaborn defusedxml nbformat prometheus_client pexpect mypy_extensions conda-content-trust werkzeug py pyls-spyder paramiko zipp traitlets astropy pandocfilters intervaltree autopep8 _ipyw_jlab_nb_ext_conf json5 mock html5lib pluggy astroid pickleshare argon2-cffi zict numpy et_xmlfile simplegeneric bleach nbclassic sniffio backports.weakref jupyterlab cffi soupsieve pygments pyparsing qt menuinst importlib_metadata path.py boto backports.functools_lru_cache yapf sip multipledispatch threadpoolctl more-itertools bokeh pyrsistent singledispatch llvmlite tifffile future conda-build pytables pyerfa xlwt conda-repo-cli alabaster anaconda-project ipython_genutils snowballstemmer mkl_fft pytz jupyter_console mkl_random sqlalchemy iniconfig pynacl appdirs spyder pathspec widgetsnbextension console_shortcut babel gevent lxml sphinxcontrib-websupport py-lief python-libarchive-c certifi powershell_shortcut cython conda watchdog pyreadline mkl-service:   0%|          | 0/343 [00:00<?, ?it/s]
# Examining conflict for sqlite ujson sphinxcontrib-jsmath cryptography contextlib2 ipywidgets urllib3 partd anaconda freetype glob2 toolz lzo dask-core jupyterlab_server sortedcollections nbclient ply jupyter_server spyder-kernels bcrypt libdeflate sympy networkx python-language-server testpath wheel notebook scipy yellowbrick nltk pytest pip comtypes backcall importlib-metadata pkginfo matplotlib-base ipython packaging pycosat jinja2 pyzmq async_generator giflib libtiff sphinxcontrib-devhelp unicodecsv jupyter_client typing_extensions pyqt xlwings attrs greenlet psutil atomicwrites pyopenssl imagesize matplotlib defusedxml mypy_extensions conda-content-trust zipp pandocfilters astroid pickleshare bleach nbclassic icu sniffio importlib_metadata backports.functools_lru_cache yapf sip more-itertools tifffile pyerfa alabaster snowballstemmer pynacl spyder widgetsnbextension py-lief certifi powershell_shortcut cython conda docutils terminado kiwisolver filelock cloudpickle brotlipy zope.event entrypoints lz4-c jupyter-packaging olefile prompt_toolkit win_unicode_console winpty joblib tbb dask setuptools snappy pillow anaconda-client zfp anyio pyodbc wincertstore vc pandas argh lazy-object-proxy requests qtpy pycurl openssl jupyter_core nose mccabe black tblib heapdict numba jdcal krb5 jedi distributed libssh2 sphinxcontrib pywin32 clyent conda-token jupyterlab_pygments openjpeg zope.interface libaec tornado numpy-base liblief patsy zope flake8 backports backports.shutil_get_terminal_size prometheus_client zstd werkzeug paramiko traitlets mock argon2-cffi zict numpy backports.weakref jupyterlab cffi soupsieve bokeh pyrsistent libcurl conda-repo-cli anaconda-project ipython_genutils mkl_random sqlalchemy iniconfig appdirs console_shortcut lxml sphinxcontrib-websupport mkl-service cytoolz h5py regex xlrd qtconsole jsonschema msgpack-python ipykernel path pyflakes libzopfli diff-match-patch nest-asyncio libiconv navigator-updater pywin32-ctypes win_inet_pton openpyxl bzip2 jupyter ruamel_yaml scikit-image sphinxcontrib-htmlhelp tqdm jupyterlab_widgets sphinxcontrib-qthelp bottleneck chardet bitarray typed-ast locket libspatialindex vs2015_runtime decorator wrapt anaconda-navigator mpmath curl sphinxcontrib-applehelp hdf5 webencodings libxml2 pep8 python-jsonrpc-server pycparser lerc seaborn py pyls-spyder _ipyw_jlab_nb_ext_conf json5 html5lib simplegeneric charls pygments pyparsing path.py multipledispatch singledispatch conda-build xlwt mkl_fft pytz jupyter_console libxslt libarchive babel gevent fastcache menuinst bkcharts pysocks toml blosc statsmodels mistune pywinpty brotli pytest-runner numpydoc rtree tk three-merge parso imagecodecs markupsafe pathlib2 beautifulsoup4 xmltodict rope yaml itsdangerous six qtawesome backports.tempfile python libpng pyyaml asn1crypto conda-package-handling scikit-learn cycler keyring python-dateutil isort fsspec sphinxcontrib-serializinghtml click sphinx idna wcwidth ptyprocess libsodium colorama pycodestyle jpeg prompt-toolkit pywavelets flask qdarkstyle textdistance imageio send2trash sortedcontainers pylint nbconvert conda-verify pydocstyle zeromq nbformat pexpect astropy intervaltree autopep8 pluggy et_xmlfile qt boto zlib threadpoolctl llvmlite future lcms2 pytables xlsxwriter numexpr pathspec python-libarchive-c watchdog pyreadline xz:   0%|          | 1/343 [00:35<3:21:53, 35.42s/it]
# Examining conflict for sqlite ujson sphinxcontrib-jsmath cryptography contextlib2 ipywidgets urllib3 partd anaconda freetype glob2 toolz lzo dask-core jupyterlab_server sortedcollections nbclient ply jupyter_server spyder-kernels bcrypt libdeflate sympy networkx python-language-server testpath wheel notebook scipy yellowbrick nltk pytest pip comtypes backcall importlib-metadata pkginfo matplotlib-base ipython packaging pycosat jinja2 pyzmq async_generator giflib libtiff sphinxcontrib-devhelp unicodecsv jupyter_client typing_extensions pyqt xlwings attrs greenlet psutil atomicwrites pyopenssl imagesize matplotlib defusedxml mypy_extensions conda-content-trust zipp pandocfilters astroid pickleshare bleach nbclassic icu sniffio importlib_metadata backports.functools_lru_cache yapf sip more-itertools tifffile pyerfa alabaster snowballstemmer pynacl spyder widgetsnbextension py-lief certifi powershell_shortcut cython conda docutils terminado kiwisolver filelock cloudpickle brotlipy zope.event entrypoints lz4-c jupyter-packaging olefile prompt_toolkit win_unicode_console winpty joblib tbb dask setuptools snappy pillow anaconda-client zfp anyio pyodbc wincertstore vc pandas argh lazy-object-proxy requests qtpy pycurl openssl jupyter_core nose mccabe black tblib heapdict numba jdcal krb5 jedi distributed libssh2 sphinxcontrib pywin32 clyent conda-token jupyterlab_pygments openjpeg zope.interface libaec tornado numpy-base liblief patsy zope flake8 backports backports.shutil_get_terminal_size prometheus_client zstd werkzeug paramiko traitlets mock argon2-cffi zict numpy backports.weakref jupyterlab cffi soupsieve bokeh pyrsistent libcurl conda-repo-cli anaconda-project ipython_genutils mkl_random sqlalchemy iniconfig appdirs console_shortcut lxml sphinxcontrib-websupport mkl-service cytoolz h5py regex xlrd qtconsole jsonschema msgpack-python ipykernel path pyflakes libzopfli diff-match-patch nest-asyncio libiconv navigator-updater pywin32-ctypes win_inet_pton openpyxl bzip2 jupyter ruamel_yaml scikit-image sphinxcontrib-htmlhelp tqdm jupyterlab_widgets sphinxcontrib-qthelp bottleneck chardet bitarray typed-ast locket libspatialindex vs2015_runtime decorator wrapt anaconda-navigator mpmath curl sphinxcontrib-applehelp hdf5 webencodings libxml2 pep8 python-jsonrpc-server pycparser lerc seaborn py pyls-spyder _ipyw_jlab_nb_ext_conf json5 html5lib simplegeneric charls pygments pyparsing path.py multipledispatch singledispatch conda-build xlwt mkl_fft pytz jupyter_console libxslt libarchive babel gevent fastcache menuinst bkcharts pysocks toml blosc statsmodels mistune pywinpty brotli pytest-runner numpydoc rtree tk three-merge parso imagecodecs markupsafe pathlib2 beautifulsoup4 xmltodict rope yaml itsdangerous six qtawesome backports.tempfile python libpng pyyaml asn1crypto conda-package-handling scikit-learn cycler keyring python-dateutil isort fsspec sphinxcontrib-serializinghtml click sphinx idna wcwidth ptyprocess libsodium colorama pycodestyle jpeg prompt-toolkit pywavelets flask qdarkstyle textdistance imageio send2trash sortedcontainers pylint nbconvert conda-verify pydocstyle zeromq nbformat pexpect astropy intervaltree autopep8 pluggy et_xmlfile qt boto zlib threadpoolctl llvmlite future lcms2 pytables xlsxwriter numexpr pathspec python-libarchive-c watchdog pyreadline xz:   1%|          | 2/343 [00:35<1:40:39, 17.71s/it]
# ...
# bokeh -> matplotlib -> matplotlib-base[version='3.1.2|3.1.2|3.1.2|3.1.3|3.1.3|3.1.3|>=3.2.1,<3.2.2.0a0|>=3.2.2,<3.2.3.0a0|>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0|>=3.3.4,<3.3.5.0a0|>=3.4.2,<3.4.3.0a0|>=3.4.3,<3.4.4.0a0',build='py38h64f37c6_1|py37h64f37c6_1|py36h64f37c6_0|py38h64f37c6_0|py37h64f37c6_0|py36h64f37c6_1']
# nltk -> matplotlib -> matplotlib-base[version='3.1.2|3.1.2|3.1.2|3.1.3|3.1.3|3.1.3|>=3.2.1,<3.2.2.0a0|>=3.2.2,<3.2.3.0a0|>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0|>=3.3.4,<3.3.5.0a0|>=3.4.2,<3.4.3.0a0|>=3.4.3,<3.4.4.0a0',build='py38h64f37c6_1|py37h64f37c6_1|py36h64f37c6_0|py38h64f37c6_0|py37h64f37c6_0|py36h64f37c6_1']
# networkx -> matplotlib[version='>=3.3'] -> matplotlib-base[version='>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0|>=3.3.4,<3.3.5.0a0|>=3.4.2,<3.4.3.0a0|>=3.4.3,<3.4.4.0a0']
#
# Package pathtools conflicts for:
# watchdog -> pathtools[version='>=0.1.1']
# spyder -> watchdog[version='>=0.10.3'] -> pathtools[version='>=0.1.1']
#
# Package statsmodels conflicts for:
# seaborn -> statsmodels[version='>=0.5.0']
# statsmodels
# anaconda==2021.05 -> statsmodels==0.12.2[build='py39h2bbff1b_0|py38h2bbff1b_0|py37h2bbff1b_0']
#
# Package glob2 conflicts for:
# conda-build -> glob2[version='>=0.6']
# anaconda==2021.05 -> glob2==0.7=pyhd3eb1b0_0
# glob2
#
# Package pydocstyle conflicts for:
# anaconda==2021.05 -> python-language-server==0.36.2=pyhd3eb1b0_0 -> pydocstyle[version='>=2.0.0']
# python-language-server -> pydocstyle[version='>=2.0.0']
# spyder -> python-lsp-server[version='>=1.2.2,<1.3.0'] -> pydocstyle[version='>=2.0.0']
# pyls-spyder -> python-lsp-server[version='>=1.0.1'] -> pydocstyle[version='>=2.0.0']
# pydocstyle
# pyls-black -> python-language-server -> pydocstyle[version='>=2.0.0']
# anaconda==2021.05 -> pydocstyle==6.0.0=pyhd3eb1b0_0
#
# Package conda-package-handling conflicts for:
# conda[version='>=4.10.3'] -> conda-package-handling[version='>=1.3.0']
# conda-token -> conda[version='>=4.3'] -> conda-package-handling[version='>=1.3.0']
# conda-build -> conda-package-handling[version='>=1.1|>=1.3']
# conda-verify -> conda-package-handling[version='>=1.0.4|>=1.1']
# conda-package-handling
# conda-build -> conda[version='>=4.5'] -> conda-package-handling[version='>=1.0.4|>=1.3.0']
#
# Package lerc conflicts for:
# lerc
# imagecodecs -> lerc[version='>=2.2.1,<3.0a0|>=3.0,<4.0a0']
# anaconda==2021.05 -> lerc==2.2.1=hd77b12b_0
# tifffile -> imagecodecs[version='>=2021.4.28'] -> lerc[version='>=2.2.1,<3.0a0|>=3.0,<4.0a0']
# anaconda==2021.05 -> imagecodecs==2021.3.31=py38h5da4933_0 -> lerc[version='>=2.2.1,<3.0a0']
#
# Package xlwt conflicts for:
# anaconda==2021.05 -> xlwt==1.3.0[build='py37_0|py39haa95532_0|py38_0']
# xlwt
#
# Package tbb4py conflicts for:
# numpy-base -> tbb4py
# mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> tbb4py
# mkl_fft -> numpy-base[version='>=1.0.6,<2.0a0'] -> tbb4py
# numpy -> numpy-base==1.15.4=py27h2753ae9_0 -> tbb4py
#
# Package mypy_extensions conflicts for:
# mypy_extensions
# anaconda==2021.05 -> black==19.10b0=py_0 -> mypy_extensions
# black -> mypy_extensions
# anaconda==2021.05 -> mypy_extensions[version='0.4.1|0.4.3|0.4.3',build='py37_0|py39haa95532_0|py38_0']
# pyls-black -> black -> mypy_extensions
#
# Package widgetsnbextension conflicts for:
# anaconda==2021.05 -> widgetsnbextension==3.5.1[build='py37_0|py39haa95532_0|py38_0']
# _ipyw_jlab_nb_ext_conf -> widgetsnbextension
# jupyter -> ipywidgets -> widgetsnbextension[version='>=3.0.0|>=3.1.0,<4.0|>=3.2.0,<4.0.0|>=3.3.0,<3.4.0|>=3.4.0,<3.5.0|>=3.5.0,<3.6.0']
# anaconda==2021.05 -> ipywidgets==7.6.3=pyhd3eb1b0_1 -> widgetsnbextension[version='>=3.5.0,<3.6.0']
# widgetsnbextension
# ipywidgets -> widgetsnbextension[version='>=3.0.0|>=3.1.0,<4.0|>=3.2.0,<4.0.0|>=3.3.0,<3.4.0|>=3.4.0,<3.5.0|>=3.5.0,<3.6.0']
# _ipyw_jlab_nb_ext_conf -> ipywidgets -> widgetsnbextension[version='>=3.0.0|>=3.1.0,<4.0|>=3.2.0,<4.0.0|>=3.3.0,<3.4.0|>=3.4.0,<3.5.0|>=3.5.0,<3.6.0']
#
# Package heapdict conflicts for:
# anaconda==2021.05 -> heapdict==1.0.1=py_0
# heapdict
# distributed -> zict[version='>=0.1.3'] -> heapdict
# anaconda==2021.05 -> zict==2.0.0=pyhd3eb1b0_0 -> heapdict
# zict -> heapdict
#
# Package m2w64-gcc-libgfortran conflicts for:
# m2w64-gcc-libs -> m2w64-gcc-libgfortran
# anaconda==2021.05 -> m2w64-gcc-libgfortran==5.3.0=6
# m2w64-gcc-libgfortran
# pywinpty -> m2w64-gcc-libs -> m2w64-gcc-libgfortran
# anaconda==2021.05 -> m2w64-gcc-libs==5.3.0=7 -> m2w64-gcc-libgfortran
#
# Package pywavelets conflicts for:
# anaconda==2021.05 -> scikit-image==0.18.1=py38hf11a4ad_0 -> pywavelets[version='>=0.4.0']
# pywavelets
# anaconda==2021.05 -> pywavelets==1.1.1[build='py38he774522_2|py39h080aedc_4|py37he774522_2']
# scikit-image -> pywavelets[version='>=0.4.0|>=1.1.1']
#
# Package navigator-updater conflicts for:
# anaconda-navigator -> navigator-updater
# navigator-updater
#
# Package typing-extensions conflicts for:
# pylint -> astroid[version='>=2.6.5,<=2.7'] -> typing-extensions[version='>=3.7.4']
# astroid -> typing-extensions[version='>=3.7.4']
#
# Package zict conflicts for:
# distributed -> zict[version='>=0.1.2|>=0.1.3']
# dask -> distributed=2021.10.0 -> zict[version='>=0.1.2|>=0.1.3']
# anaconda==2021.05 -> zict==2.0.0=pyhd3eb1b0_0
# anaconda==2021.05 -> distributed==2021.4.0=py38haa95532_0 -> zict[version='>=0.1.3']
# zict
#
# Package parso conflicts for:
# spyder -> jedi[version='>=0.17.2,<0.19.0'] -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0|>=0.3.0|>=0.5.0|>=0.7.0,<0.8.0|>=0.8.0,<0.9.0|>=0.7.0|>=0.5.2']
# parso
# anaconda==2021.05 -> jedi==0.17.2=py38haa95532_1 -> parso[version='0.7.0.*|>=0.7.0,<0.8.0']
# anaconda==2021.05 -> parso==0.7.0=py_0
# ipython -> jedi[version='>=0.16,<1.0'] -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0|>=0.3.0|>=0.5.0|>=0.5.2|>=0.7.0|>=0.7.0,<0.8.0|>=0.8.0,<0.9.0']
# jedi -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0|>=0.3.0|>=0.5.0|>=0.5.2|>=0.7.0|>=0.7.0,<0.8.0|>=0.8.0,<0.9.0']
# spyder -> parso[version='0.5.2.*|0.7.0.*|>=0.7.0,<0.9.0']
# python-language-server -> jedi[version='>=0.17.2,<0.18.0a0'] -> parso[version='>=0.5.0|>=0.7.0|>=0.7.0,<0.8.0']
#
# Package pyls-spyder conflicts for:
# anaconda==2021.05 -> pyls-spyder==0.3.2=pyhd3eb1b0_0
# spyder -> pyls-spyder[version='>=0.1.1|>=0.3.0|>=0.3.2|>=0.3.2,<0.4.0|>=0.4.0']
# anaconda==2021.05 -> spyder==4.2.5=py38haa95532_0 -> pyls-spyder[version='>=0.3.2']
# pyls-spyder
#
# Package get_terminal_size conflicts for:
# anaconda==2021.05 -> get_terminal_size==1.0.0=h38e98db_0
# get_terminal_size
#
# Package _low_priority conflicts for:
# libarchive -> _low_priority
# python-libarchive-c -> libarchive -> _low_priority
# conda-build -> libarchive -> _low_priority
#
# Package python-lsp-server conflicts for:
# spyder -> python-lsp-server[version='>=1.2.2,<1.3.0']
# spyder -> pyls-spyder[version='>=0.4.0'] -> python-lsp-server[version='>=1.0.1']
#
# Package numexpr conflicts for:
# dask -> pandas[version='>=1.0'] -> numexpr[version='>=2.6.8|>=2.7.0']
# pandas -> numexpr[version='>=2.6.8|>=2.7.0']
# networkx -> pandas[version='>=1.1'] -> numexpr[version='>=2.6.8|>=2.7.0']
# anaconda==2021.05 -> pytables==3.6.1=py38ha5be198_0 -> numexpr
# pytables -> numexpr
# bkcharts -> pandas -> numexpr[version='>=2.6.8|>=2.7.0']
# anaconda==2021.05 -> numexpr==2.7.3[build='py39hb80d3ca_1|py38hb80d3ca_1|py37hb80d3ca_1']
# bokeh -> pandas -> numexpr[version='>=2.6.8|>=2.7.0']
# numexpr
# statsmodels -> pandas[version='>=1.0'] -> numexpr[version='>=2.6.8|>=2.7.0']
# seaborn -> pandas[version='>=0.23'] -> numexpr[version='>=2.6.8|>=2.7.0']
#
# Package libzopfli conflicts for:
# tifffile -> imagecodecs[version='>=2021.4.28'] -> libzopfli[version='>=1.0.3,<1.1.0a0']
# imagecodecs -> libzopfli[version='>=1.0.3,<1.1.0a0']
# libzopfli
# anaconda==2021.05 -> libzopfli==1.0.3=ha925a31_0
# anaconda==2021.05 -> imagecodecs==2021.3.31=py38h5da4933_0 -> libzopfli[version='>=1.0.3,<1.1.0a0']
#
# Package pytest-runner conflicts for:
# pytest-runner
# yellowbrick -> pytest-runner
#
# Package pyasn1 conflicts for:
# paramiko -> pyasn1[version='>=0.1.7']
# spyder -> paramiko[version='>=2.4.0'] -> pyasn1[version='>=0.1.7']
# prometheus_client -> twisted -> pyasn1
#
# Package scandir conflicts for:
# pickleshare -> pathlib2 -> scandir
# importlib_metadata -> pathlib2 -> scandir
# testpath -> pathlib2 -> scandir
# pathlib2 -> scandir
# conda-build -> scandir
# pytest -> pathlib2[version='>=2.2.0'] -> scandir
# ipython -> pathlib2 -> scandir
#
# Package jupyter conflicts for:
# jupyter
# anaconda==2021.05 -> jupyter==1.0.0[build='py37_7|py38_7|py39haa95532_7']
#
# Package liblief conflicts for:
# py-lief -> liblief[version='0.10.1|0.9.0|0.9.0|0.9.0',build='ha925a31_0|ha925a31_3|ha925a31_0|hd77b12b_1|ha925a31_2']
# liblief
# conda-build -> py-lief -> liblief[version='0.10.1|0.9.0|0.9.0|0.9.0',build='ha925a31_0|ha925a31_3|ha925a31_0|hd77b12b_1|ha925a31_2']
# anaconda==2021.05 -> liblief==0.10.1[build='ha925a31_0|hd77b12b_1']
#
# Package m2w64-gmp conflicts for:
# anaconda==2021.05 -> m2w64-gcc-libs==5.3.0=7 -> m2w64-gmp
# m2w64-gcc-libs-core -> m2w64-gmp
# pywinpty -> m2w64-gcc-libs -> m2w64-gmp
# m2w64-gmp
# m2w64-gcc-libgfortran -> m2w64-gcc-libs-core -> m2w64-gmp
# m2w64-gcc-libs -> m2w64-gmp
# anaconda==2021.05 -> m2w64-gmp==6.1.0=2
#
# Package astropy conflicts for:
# anaconda==2021.05 -> astropy==4.2.1[build='py37h2bbff1b_1|py38h2bbff1b_1|py39h2bbff1b_1']
# astropy
#
# Package libllvm9 conflicts for:
# numba -> llvmlite[version='>=0.33.0'] -> libllvm9
# llvmlite -> libllvm9
#
# Package sphinxcontrib-serializinghtml conflicts for:
# sphinxcontrib-serializinghtml
# spyder -> sphinx[version='>=0.6.6'] -> sphinxcontrib-serializinghtml[version='>=1.1.5']
# numpydoc -> sphinx -> sphinxcontrib-serializinghtml[version='>=1.1.5']
# anaconda==2021.05 -> sphinx==4.0.1=pyhd3eb1b0_0 -> sphinxcontrib-serializinghtml
# sphinx -> sphinxcontrib-serializinghtml[version='>=1.1.5']
# anaconda==2021.05 -> sphinxcontrib-serializinghtml==1.1.4=pyhd3eb1b0_0
#
# Package conda-repo-cli conflicts for:
# conda-repo-cli
# anaconda-navigator -> conda-repo-cli
#
# Package fonttools conflicts for:
# matplotlib-base -> fonttools[version='>=4.22.0']
# scikit-image -> matplotlib-base[version='>=2.0.0,!=3.0.0'] -> fonttools[version='>=4.22.0']
# matplotlib -> matplotlib-base[version='>=3.4.3,<3.4.4.0a0'] -> fonttools[version='>=4.22.0']
#
# Package pycurl conflicts for:
# pycurl
# anaconda==2021.05 -> pycurl==7.43.0.6[build='py38h7a1dbc1_0|py39h8b3b064_0|py37h7a1dbc1_0']
#
# Package pyopenssl conflicts for:
# conda[version='>=4.10.3'] -> pyopenssl[version='>=16.2.0']
# requests -> urllib3[version='>=1.21.1,<1.27'] -> pyopenssl[version='>=0.14']
# prometheus_client -> twisted -> pyopenssl[version='>=16.0.0']
# conda-token -> conda[version='>=4.3'] -> pyopenssl[version='>=16.2.0']
# urllib3 -> pyopenssl[version='>=0.14']
# anaconda==2021.05 -> urllib3==1.26.4=pyhd3eb1b0_0 -> pyopenssl[version='>=0.14']
# conda-build -> conda[version='>=4.5'] -> pyopenssl[version='>=16.2.0']
# pyopenssl
# anaconda==2021.05 -> pyopenssl==20.0.1=pyhd3eb1b0_1
#
# Package soupsieve conflicts for:
# anaconda==2021.05 -> soupsieve==2.2.1=pyhd3eb1b0_0
# conda-build -> beautifulsoup4 -> soupsieve[version='>=1.2']
# beautifulsoup4 -> soupsieve[version='>=1.2']
# soupsieve
# anaconda==2021.05 -> beautifulsoup4==4.9.3=pyha847dfd_0 -> soupsieve[version='>=1.2']
#
# Package ply conflicts for:
# anaconda==2021.05 -> ply==3.11[build='py37_0|py39haa95532_0|py38_0']
# ply
#
# Package jupyter-packaging conflicts for:
# jupyterlab -> jupyter-packaging[version='>=0.7.3,<0.8.0']
# anaconda==2021.05 -> jupyter-packaging==0.7.12=pyhd3eb1b0_0
# _ipyw_jlab_nb_ext_conf -> jupyterlab -> jupyter-packaging[version='>=0.7.3,<0.8.0']
# jupyter-packaging
# anaconda==2021.05 -> jupyterlab==3.0.14=pyhd3eb1b0_1 -> jupyter-packaging[version='>=0.7.3,<0.8.0']
#
# Package llvmlite conflicts for:
# numba -> llvmlite[version='0.20.*|0.21.*|0.22.*|0.23.*|0.24.*|>=0.25.0,<0.26.0a0|>=0.26.0,<0.27.0a0|>=0.27.0,<0.28.0a0|>=0.28.0,<0.29.0a0|>=0.29.0,<0.30.0a0|>=0.29.0|>=0.30.0,<0.31.0a0|>=0.30.0|>=0.31.0,<0.32.0a0|>=0.31.0|>=0.32.0,<0.33.0a0|>=0.32.0|>=0.32.1,<0.33.0a0|>=0.32.1|>=0.33.0,<0.34.0a0|>=0.33.0|>=0.34.0,<0.35|>=0.35.0,<0.36.0a0|>=0.36.0,<0.37.0a0|>=0.37.0,<0.38.0a0']
# llvmlite
# anaconda==2021.05 -> llvmlite==0.36.0[build='py37h34b8924_4|py39h34b8924_4|py38h34b8924_4']
# anaconda==2021.05 -> numba==0.53.1=py38hf11a4ad_0 -> llvmlite[version='>=0.36.0,<0.37.0a0']
#
# Package lxml conflicts for:
# lxml
# anaconda==2021.05 -> lxml==4.6.3[build='py37h9b66d53_0|py38h9b66d53_0|py39h9b66d53_0']
#
# Package wrapt conflicts for:
# pylint -> astroid[version='>=2.6.5,<=2.7'] -> wrapt[version='1.11.*|>=1.11,<1.13|>=1.11,<2']
# wrapt
# astroid -> wrapt[version='1.11.*|>=1.11,<1.13|>=1.11,<2']
# anaconda==2021.05 -> wrapt==1.12.1[build='py37he774522_1|py38he774522_1|py39h196d8e1_1']
# anaconda==2021.05 -> astroid==2.5=py38haa95532_1 -> wrapt[version='>=1.11,<2']
#
# Package filelock conflicts for:
# conda-build -> filelock
# filelock
# anaconda==2021.05 -> filelock==3.0.12=pyhd3eb1b0_1
#
# Package pytables conflicts for:
# pytables
# anaconda==2021.05 -> pytables==3.6.1[build='py37h1da0976_0|py38ha5be198_0|py39h56d22b6_1']
#
# Package pywin32-ctypes conflicts for:
# keyring -> pywin32-ctypes[version='!=0.1.0,!=0.1.1']
# spyder -> keyring[version='>=17.0.0'] -> pywin32-ctypes[version='!=0.1.0,!=0.1.1']
# pywin32-ctypes
# anaconda==2021.05 -> keyring==22.3.0=py38haa95532_0 -> pywin32-ctypes
# anaconda==2021.05 -> pywin32-ctypes==0.2.0[build='py38_1000|py39haa95532_1000|py37_1001']
#
# Package nose conflicts for:
# anaconda==2021.05 -> nose==1.3.7=pyhd3eb1b0_1006
# nose
#
# Package multipledispatch conflicts for:
# anaconda==2021.05 -> multipledispatch==0.6.0[build='py37_0|py39haa95532_0|py38_0']
# multipledispatch
#
# Package xlsxwriter conflicts for:
# xlsxwriter
# anaconda==2021.05 -> xlsxwriter==1.3.8=pyhd3eb1b0_0
#
# Package jaraco.itertools conflicts for:
# zipp -> jaraco.itertools
# importlib-metadata -> zipp[version='>=0.5'] -> jaraco.itertools
# importlib_metadata -> zipp[version='>=0.5'] -> jaraco.itertools
#
# Package unicodecsv conflicts for:
# unicodecsv
# anaconda==2021.05 -> unicodecsv==0.14.1[build='py37_0|py39haa95532_0|py38_0']
#
# Package pbr conflicts for:
# mock -> pbr
# pytables -> mock -> pbr
#
# Package mock conflicts for:
# pytables -> mock
# mock
# anaconda==2021.05 -> mock==4.0.3=pyhd3eb1b0_0
# anaconda==2021.05 -> pytables==3.6.1=py38ha5be198_0 -> mock
#
# Package pyreadline conflicts for:
# anaconda==2021.05 -> pyreadline==2.1[build='py37_1|py38_1|py39haa95532_1']
# anaconda==2021.05 -> h5py==2.10.0=py38h5e291fa_0 -> pyreadline
# h5py -> pyreadline
# pyreadline
#
# Package paramiko conflicts for:
# anaconda==2021.05 -> spyder==4.2.5=py38haa95532_0 -> paramiko[version='>=2.4.0']
# spyder -> paramiko[version='>=2.4.0']
# paramiko
# anaconda==2021.05 -> paramiko==2.7.2=py_0
#
# Package regex conflicts for:
# nltk -> regex[version='>=2021.8.3']
# anaconda==2021.05 -> regex==2021.4.4[build='py39h2bbff1b_0|py38h2bbff1b_0|py37h2bbff1b_0']
# anaconda==2021.05 -> black==19.10b0=py_0 -> regex
# black -> regex
# pyls-black -> black -> regex
# regex
#
# Package sqlalchemy conflicts for:
# sqlalchemy
# anaconda==2021.05 -> sqlalchemy==1.4.7[build='py39h2bbff1b_0|py38h2bbff1b_0|py37h2bbff1b_0']
#
# Package seaborn conflicts for:
# seaborn
# anaconda==2021.05 -> seaborn==0.11.1=pyhd3eb1b0_0
#
# Package xlwings conflicts for:
# xlwings
# anaconda==2021.05 -> xlwings==0.23.0[build='py37haa95532_0|py39haa95532_0|py38haa95532_0']
#
# Package backports.shutil_which conflicts for:
# terminado -> pywinpty -> backports.shutil_which
# pywinpty -> backports.shutil_which
#
# Package gevent conflicts for:
# gevent
# anaconda==2021.05 -> gevent==21.1.2[build='py37h2bbff1b_1|py38h2bbff1b_1|py39h2bbff1b_1']
#
# Package conda-token conflicts for:
# conda-token
# anaconda-navigator -> conda-token
#
# Package immutables conflicts for:
# sniffio -> contextvars[version='>=2.1'] -> immutables[version='>=0.9']
# distributed -> contextvars -> immutables[version='>=0.9']
#
# Package bitarray conflicts for:
# bitarray
# anaconda==2021.05 -> bitarray==1.9.2[build='py37h2bbff1b_1|py38h2bbff1b_1|py39h2bbff1b_1']
#
# Package conda-pack conflicts for:
# anaconda-project -> conda-pack
# anaconda-navigator -> anaconda-project -> conda-pack
#
# Package console_shortcut conflicts for:
# console_shortcut
# anaconda==2021.05 -> console_shortcut==0.1.1=4

# %%
conda update conda
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install python=3.7 anaconda=custom
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::conda-build==3.21.4=py38haa95532_0
#
# Building graph of deps:   0%|          | 0/357 [00:00<?, ?it/s]
# Examining ipython:   0%|          | 0/357 [00:00<?, ?it/s]
# Examining pycosat:   0%|          | 1/357 [00:02<13:46,  2.32s/it]
# Examining pycosat:   1%|          | 2/357 [00:02<06:52,  1.16s/it]
# Examining lzo:   1%|          | 2/357 [00:02<06:52,  1.16s/it]
# Examining diff-match-patch:   1%|          | 3/357 [00:02<06:51,  1.16s/it]
# Examining attrs:   1%|1         | 4/357 [00:02<06:49,  1.16s/it]
# Examining zipp:   1%|1         | 5/357 [00:02<06:48,  1.16s/it]
# Examining zipp:   2%|1         | 6/357 [00:02<02:01,  2.88it/s]
# Examining nbclient:   2%|1         | 6/357 [00:02<02:01,  2.88it/s]
# Examining nbclient:   2%|1         | 7/357 [00:02<01:45,  3.32it/s]
# Examining anaconda-project:   2%|1         | 7/357 [00:02<01:45,  3.32it/s]
# Examining vc:   2%|2         | 8/357 [00:03<01:45,  3.32it/s]
# Examining vc:   3%|2         | 9/357 [00:03<01:39,  3.51it/s]
# Examining mpmath:   3%|2         | 9/357 [00:03<01:39,  3.51it/s]
# Examining console_shortcut:   3%|2         | 10/357 [00:03<01:38,  3.51it/s]
# Examining xlsxwriter:   3%|3         | 11/357 [00:03<01:38,  3.51it/s]
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Examining libsodium:   3%|3         | 12/357 [00:03<01:38,  3.51it/s]
# Examining libsodium:   4%|3         | 13/357 [00:03<00:59,  5.74it/s]
# Examining jupyter:   4%|3         | 13/357 [00:03<00:59,  5.74it/s]
# Examining pyyaml:   4%|3         | 14/357 [00:05<00:59,  5.74it/s]
# Examining pyyaml:   4%|4         | 15/357 [00:05<02:05,  2.73it/s]
# Examining traitlets:   4%|4         | 15/357 [00:05<02:05,  2.73it/s]
# Examining traitlets:   4%|4         | 16/357 [00:05<01:51,  3.06it/s]
# Examining contextlib2:   4%|4         | 16/357 [00:05<01:51,  3.06it/s]
# Examining locket:   5%|4         | 17/357 [00:05<01:51,  3.06it/s]
# Examining pillow:   5%|5         | 18/357 [00:05<01:50,  3.06it/s]
# Examining pillow:   5%|5         | 19/357 [00:05<01:10,  4.80it/s]
# Examining isort:   5%|5         | 19/357 [00:05<01:10,  4.80it/s]
# Examining nltk:   6%|5         | 20/357 [00:06<01:10,  4.80it/s]
# Examining nltk:   6%|5         | 21/357 [00:06<02:00,  2.79it/s]
# Examining psutil:   6%|5         | 21/357 [00:07<02:00,  2.79it/s]
# Examining psutil:   6%|6         | 22/357 [00:07<02:04,  2.69it/s]
# Examining three-merge:   6%|6         | 22/357 [00:07<02:04,  2.69it/s]
# Examining three-merge:   6%|6         | 23/357 [00:07<01:48,  3.08it/s]
# Examining atomicwrites:   6%|6         | 23/357 [00:07<01:48,  3.08it/s]
# Examining appdirs:   7%|6         | 24/357 [00:07<01:47,  3.08it/s]
# Examining typing_extensions:   7%|7         | 25/357 [00:07<01:47,  3.08it/s]
# Examining typing_extensions:   7%|7         | 26/357 [00:07<01:04,  5.15it/s]
# Examining boto:   7%|7         | 26/357 [00:07<01:04,  5.15it/s]
# Examining pickleshare:   8%|7         | 27/357 [00:07<01:04,  5.15it/s]
# Examining fsspec:   8%|7         | 28/357 [00:07<01:03,  5.15it/s]
# Examining fsspec:   8%|8         | 29/357 [00:07<00:44,  7.44it/s]
# Examining alabaster:   8%|8         | 29/357 [00:07<00:44,  7.44it/s]
# Examining pyrsistent:   8%|8         | 30/357 [00:07<00:43,  7.44it/s]
# Examining pyrsistent:   9%|8         | 31/357 [00:07<00:39,  8.23it/s]
# Examining yaml:   9%|8         | 31/357 [00:08<00:39,  8.23it/s]
# Examining markupsafe:   9%|8         | 32/357 [00:08<00:39,  8.23it/s]
# Examining matplotlib-base:   9%|9         | 33/357 [00:08<00:39,  8.23it/s]
# Examining matplotlib-base:  10%|9         | 34/357 [00:08<00:30, 10.64it/s]
# Examining tk:  10%|9         | 34/357 [00:09<00:30, 10.64it/s]
# Examining jupyter_core:  10%|9         | 35/357 [00:09<00:30, 10.64it/s]
# Examining jupyter_core:  10%|#         | 36/357 [00:09<01:23,  3.83it/s]
# Examining jupyterlab_widgets:  10%|#         | 36/357 [00:09<01:23,  3.83it/s]
# Examining @/win-64::__win==0=0:  10%|#         | 37/357 [00:09<01:23,  3.83it/s]
# Examining @/win-64::__win==0=0:  11%|#         | 38/357 [00:09<01:08,  4.64it/s]
# Examining singledispatch:  11%|#         | 38/357 [00:09<01:08,  4.64it/s]
# Examining iniconfig:  11%|#         | 39/357 [00:09<01:08,  4.64it/s]
# Examining sphinxcontrib-htmlhelp:  11%|#1        | 40/357 [00:09<01:08,  4.64it/s]
# Examining sphinxcontrib-htmlhelp:  11%|#1        | 41/357 [00:09<00:47,  6.59it/s]
# Examining numpy:  11%|#1        | 41/357 [00:09<00:47,  6.59it/s]
# Examining blosc:  12%|#1        | 42/357 [00:12<00:47,  6.59it/s]
# Examining blosc:  12%|#2        | 43/357 [00:12<02:12,  2.38it/s]
# Examining imageio:  12%|#2        | 43/357 [00:12<02:12,  2.38it/s]
# Examining pytest-runner:  12%|#2        | 44/357 [00:13<02:11,  2.38it/s]
# Examining pytest-runner:  13%|#2        | 45/357 [00:13<02:36,  1.99it/s]
# Examining tqdm:  13%|#2        | 45/357 [00:15<02:36,  1.99it/s]
# Examining tqdm:  13%|#2        | 46/357 [00:15<03:45,  1.38it/s]
# Examining qdarkstyle:  13%|#2        | 46/357 [00:16<03:45,  1.38it/s]
# Examining qdarkstyle:  13%|#3        | 47/357 [00:16<03:26,  1.50it/s]
# Examining qtpy:  13%|#3        | 47/357 [00:16<03:26,  1.50it/s]
# Examining numpydoc:  13%|#3        | 48/357 [00:16<03:25,  1.50it/s]
# Examining numpydoc:  14%|#3        | 49/357 [00:16<02:21,  2.17it/s]
# Examining freetype:  14%|#3        | 49/357 [00:16<02:21,  2.17it/s]
# Examining freetype:  14%|#4        | 50/357 [00:16<02:22,  2.16it/s]
# Examining toolz:  14%|#4        | 50/357 [00:16<02:22,  2.16it/s]
# Examining sqlite:  14%|#4        | 51/357 [00:16<02:21,  2.16it/s]
# Examining threadpoolctl:  15%|#4        | 52/357 [00:16<02:21,  2.16it/s]
# Examining colorama:  15%|#4        | 53/357 [00:16<02:20,  2.16it/s]
# Examining simplegeneric:  15%|#5        | 54/357 [00:16<02:20,  2.16it/s]
# Examining simplegeneric:  15%|#5        | 55/357 [00:16<01:03,  4.74it/s]
# Examining jsonschema:  15%|#5        | 55/357 [00:16<01:03,  4.74it/s]
# Examining libxslt:  16%|#5        | 56/357 [00:17<01:03,  4.74it/s]
# Examining libxslt:  16%|#5        | 57/357 [00:17<01:12,  4.16it/s]
# Examining openjpeg:  16%|#5        | 57/357 [00:17<01:12,  4.16it/s]
# Examining cycler:  16%|#6        | 58/357 [00:17<01:11,  4.16it/s]
# Examining dask-core:  17%|#6        | 59/357 [00:17<01:11,  4.16it/s]
# Examining olefile:  17%|#6        | 60/357 [00:18<01:11,  4.16it/s]
# Examining olefile:  17%|#7        | 61/357 [00:18<01:06,  4.44it/s]
# Examining libzopfli:  33%|###2      | 117/357 [00:28<01:38,  2.44it/s]
# Examining blas:  33%|###2      | 117/357 [00:28<01:38,  2.44it/s]
# Examining zope.event:  33%|###3      | 118/357 [00:28<01:37,  2.44it/s]
# Examining seaborn:  33%|###3      | 119/357 [00:28<01:37,  2.44it/s]
# Examining seaborn:  34%|###3      | 120/357 [00:28<01:02,  3.78it/s]
# Examining sip:  34%|###3      | 120/357 [00:30<01:02,  3.78it/s]
# Examining sip:  34%|###3      | 121/357 [00:30<02:06,  1.87it/s]
# Examining giflib:  34%|###3      | 121/357 [00:30<02:06,  1.87it/s]
# Examining widgetsnbextension:  34%|###4      | 122/357 [00:30<02:05,  1.87it/s]
# Examining sphinxcontrib:  34%|###4      | 123/357 [00:32<02:05,  1.87it/s]
# Examining sphinxcontrib:  35%|###4      | 124/357 [00:32<02:21,  1.65it/s]
# Examining textdistance:  35%|###4      | 124/357 [00:32<02:21,  1.65it/s]
# Examining autopep8:  35%|###5      | 125/357 [00:32<02:20,  1.65it/s]
# Examining cython:  35%|###5      | 126/357 [00:32<02:20,  1.65it/s]
# Examining kiwisolver:  36%|###5      | 127/357 [00:34<02:19,  1.65it/s]
# Examining kiwisolver:  36%|###5      | 128/357 [00:34<01:56,  1.96it/s]
# Examining bcrypt:  36%|###5      | 128/357 [00:34<01:56,  1.96it/s]
# Examining heapdict:  36%|###6      | 129/357 [00:34<01:56,  1.96it/s]
# Examining heapdict:  36%|###6      | 130/357 [00:34<01:36,  2.35it/s]
# Examining intervaltree:  36%|###6      | 130/357 [00:34<01:36,  2.35it/s]
# Examining asn1crypto:  37%|###6      | 131/357 [00:34<01:36,  2.35it/s]
# Examining terminado:  37%|###6      | 132/357 [00:34<01:35,  2.35it/s]
# Examining terminado:  37%|###7      | 133/357 [00:34<01:06,  3.36it/s]
# Examining ca-certificates:  37%|###7      | 133/357 [00:35<01:06,  3.36it/s]
# Examining ca-certificates:  38%|###7      | 134/357 [00:35<01:03,  3.51it/s]
# Examining setuptools:  38%|###7      | 134/357 [00:35<01:03,  3.51it/s]
# Examining icc_rt:  38%|###7      | 135/357 [00:35<01:03,  3.51it/s]
# Examining icc_rt:  38%|###8      | 136/357 [00:35<01:12,  3.04it/s]
# Examining certifi:  38%|###8      | 136/357 [00:35<01:12,  3.04it/s]
# Examining argh:  38%|###8      | 137/357 [00:36<01:12,  3.04it/s]
# Examining argh:  39%|###8      | 138/357 [00:36<00:56,  3.87it/s]
# Examining async_generator:  39%|###8      | 138/357 [00:36<00:56,  3.87it/s]
# Examining nest-asyncio:  39%|###8      | 139/357 [00:36<00:56,  3.87it/s]
# Examining pyflakes:  39%|###9      | 140/357 [00:36<00:56,  3.87it/s]
# Examining pyzmq:  39%|###9      | 141/357 [00:36<00:55,  3.87it/s]
# Examining pyzmq:  40%|###9      | 142/357 [00:36<00:35,  6.10it/s]
# Examining tifffile:  40%|###9      | 142/357 [00:36<00:35,  6.10it/s]
# Examining vs2015_runtime:  40%|####      | 143/357 [00:37<00:35,  6.10it/s]
# Examining vs2015_runtime:  40%|####      | 144/357 [00:37<00:56,  3.76it/s]
# Examining comtypes:  55%|#####5    | 198/357 [01:22<04:29,  1.69s/it]
# Examining comtypes:  56%|#####5    | 199/357 [01:22<03:33,  1.35s/it]
# Examining lxml:  56%|#####5    | 199/357 [01:22<03:33,  1.35s/it]
# Examining yapf:  56%|#####6    | 200/357 [01:22<03:32,  1.35s/it]
# Examining yapf:  56%|#####6    | 201/357 [01:22<02:47,  1.08s/it]
# Examining backports.shutil_get_terminal_size:  56%|#####6    | 201/357 [01:22<02:47,  1.08s/it]
# Examining anaconda-client:  57%|#####6    | 202/357 [01:22<02:46,  1.08s/it]
# Examining future:  57%|#####6    | 203/357 [01:24<02:45,  1.08s/it]
# Examining future:  57%|#####7    | 204/357 [01:24<02:14,  1.14it/s]
# Examining pywinpty:  57%|#####7    | 204/357 [01:24<02:14,  1.14it/s]
# Examining win_inet_pton:  57%|#####7    | 205/357 [01:24<02:13,  1.14it/s]
# Examining win_inet_pton:  58%|#####7    | 206/357 [01:24<01:43,  1.46it/s]
# Examining watchdog:  58%|#####7    | 206/357 [01:24<01:43,  1.46it/s]
# Examining astroid:  58%|#####7    | 207/357 [01:24<01:42,  1.46it/s]
# Examining astroid:  58%|#####8    | 208/357 [01:24<01:20,  1.86it/s]
# Examining conda-token:  58%|#####8    | 208/357 [01:26<01:20,  1.86it/s]
# Examining h5py:  59%|#####8    | 209/357 [01:27<01:19,  1.86it/s]
# Examining h5py:  59%|#####8    | 210/357 [01:27<01:47,  1.37it/s]
# Examining pandoc:  59%|#####8    | 210/357 [01:28<01:47,  1.37it/s]
# Examining pandoc:  59%|#####9    | 211/357 [01:28<02:12,  1.10it/s]
# Examining pycurl:  59%|#####9    | 211/357 [01:28<02:12,  1.10it/s]
# Examining qtconsole:  59%|#####9    | 212/357 [01:29<02:11,  1.10it/s]
# Examining qtconsole:  60%|#####9    | 213/357 [01:29<01:32,  1.55it/s]
# Examining llvmlite:  60%|#####9    | 213/357 [01:30<01:32,  1.55it/s]

# %%
from pyspark import SparkContext
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13028/72600002.py in <module>
# ----> 1 from pyspark import SparkContext
#
# C:\spark\python\pyspark\__init__.py in <module>
#      44
#      45 from pyspark.conf import SparkConf
# ---> 46 from pyspark.context import SparkContext
#      47 from pyspark.rdd import RDD
#      48 from pyspark.files import SparkFiles
#
# C:\spark\python\pyspark\context.py in <module>
#      29 from py4j.protocol import Py4JError
#      30
# ---> 31 from pyspark import accumulators
#      32 from pyspark.accumulators import Accumulator
#      33 from pyspark.broadcast import Broadcast, BroadcastPickleRegistry
#
# C:\spark\python\pyspark\accumulators.py in <module>
#      95     import socketserver as SocketServer
#      96 import threading
# ---> 97 from pyspark.cloudpickle import CloudPickler
#      98 from pyspark.serializers import read_int, PickleSerializer
#      99
#
# C:\spark\python\pyspark\cloudpickle.py in <module>
#     144
#     145
# --> 146 _cell_set_template_code = _make_cell_set_template_code()
#     147
#     148
#
# C:\spark\python\pyspark\cloudpickle.py in _make_cell_set_template_code()
#     125         )
#     126     else:
# --> 127         return types.CodeType(
#     128             co.co_argcount,
#     129             co.co_kwonlyargcount,
#
# TypeError: an integer is required (got type bytes)
